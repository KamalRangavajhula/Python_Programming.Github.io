# %%
import pandas as pd

# %%
churn = pd.read_csv('C:/Users/kamalsaran/Desktop/bader/Churn_Modelling.csv')

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null int64
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null object
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
churn.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France       0   42
# 1          2    15647311      Hill          608     Spain       0   41
# 2          3    15619304      Onio          502    France       0   42
# 3          4    15701354      Boni          699    France       0   39
# 4          5    15737888  Mitchell          850     Spain       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88    Exit
# 1        112542.58  Stayed
# 2        113931.57    Exit
# 3         93826.63  Stayed
# ...

# %%
churn.plot.scatter(x='CreditScore', y='EstimatedSalary', c='blue', s=9, figsize =(11,8))

# %%
churn['CreditScore'].plot.hist(bins = 20)

# %%
plt.style.use('ggplot')

# %%
churn['Balance'].plot.hist(alpha = 0.3, bins =25)

# %%
churn['CreditScore'].plot.box()

# %%
churn['Age'].plot.kde()

# %%
churn['Age'].plot.density(lw=3, ls ='--')

# %%
churn.plt.line()
